# %%
import grading_analysis as grading

# %%
grading.process_grades(report="Q1", grade=True)
# Out:
# Grades for Q1:
#    Initials   Q1
# 0      JEVE  2.0
# 1      LFGG  4.5
# 2      CACB  5.0
# 3      MARG  0.0
# 4       JCP  1.0
# 5       SSP  4.5
# 6        MD  0.0
# 7        MC  5.0
# 8       AAB  4.5
# 9      LMCR  3.0
# 10     MCGG  4.5
# 11     WECM  0.5
# 12      MPV  5.0
# 13     AJCS  3.0
# 14     LJMG  4.0
# 15      MAF  0.0
# 16       AC  0.0
# 17      JDZ  0.0
# 18       AZ  0.0
# 19      NaN  0.0
#
# Statistical Analysis:
# Mean: 3.58
# Median: 4.50
# Standard Deviation: 1.55
# Minimum: 0.50
# Maximum: 5.00
# Number of Submissions: 13
