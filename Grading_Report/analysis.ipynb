# %%
import grading_analysis as grading

# %%
grading.process_grades(report="Q2", grade=True)
# Out:
# Grades for Q2:
#    Initials  Q2
# 0      JEVE   5
# 1      LFGG   5
# 2      CACB   5
# 3      MARG   0
# 4       JCP   5
# 5       SSP   5
# 6        MD   3
# 7        MC   5
# 8       AAB   5
# 9      LMCR   5
# 10     MCGG   5
# 11     WECM   5
# 12      MPV   5
# 13     AJCS   3
# 14     LJMG   5
# 15      SHP   0
# 16       AC   0
# 17      JDZ   0
# 18       AZ   0
# 19       NN   0
#
# This analysis only considered the number of submissions (don't include zeros)
#
# Statistical Analysis:
# Number of Submissions: 14
# Mean: 4.71
# Median: 5.00
# Standard Deviation: 0.73
# Minimum: 3.00
# Maximum: 5.00
